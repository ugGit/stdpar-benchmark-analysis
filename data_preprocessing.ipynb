# %%
import pandas as pd
import re

# %%
import loader

src_dir = './data'
benchmarks = loader.load_benchmarks_from_dir(src_dir)

# %%
df = pd.DataFrame(benchmarks)
df
# Out:
#                                                   name  family_index  \
# 0    BM_CCA/cca_simplified_sv/DatasetFileIndex:0/ma...             0
# 1    BM_CCA/cca_simplified_sv/DatasetFileIndex:1/ma...             0
# 2    BM_CCA/cca_simplified_sv/DatasetFileIndex:2/ma...             0
# 3    BM_CCA/cca_simplified_sv/DatasetFileIndex:3/ma...             0
# 4    BM_CCA/cca_simplified_sv/DatasetFileIndex:4/ma...             0
# ..                                                 ...           ...
# 307  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...             0
# 308  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...             0
# 309  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...             0
# 310  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...             0
# 311  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...             0
#
#      per_family_instance_index  \
# 0                            0
# 1                            1
# 2                            2
# 3                            3
# 4                            4
# ..                         ...
# 307                          1
# 308                          2
# 309                          3
# 310                          4
# 311                          5
#
#                                               run_name   run_type  \
# 0    BM_CCA/cca_simplified_sv/DatasetFileIndex:0/ma...  iteration
# 1    BM_CCA/cca_simplified_sv/DatasetFileIndex:1/ma...  iteration
# 2    BM_CCA/cca_simplified_sv/DatasetFileIndex:2/ma...  iteration
# 3    BM_CCA/cca_simplified_sv/DatasetFileIndex:3/ma...  iteration
# 4    BM_CCA/cca_simplified_sv/DatasetFileIndex:4/ma...  iteration
# ..                                                 ...        ...
# 307  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...  iteration
# 308  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...  iteration
# 309  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...  iteration
# 310  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...  iteration
# 311  BM_CCA/cca_stdpar_sparse_ccl/DatasetFileIndex:...  iteration
#
#      repetitions  repetition_index  threads  iterations   real_time  \
# 0              1                 0        1          33   21.277545
# 1              1                 0        1          20   34.963654
# 2              1                 0        1          16   44.425600
# 3              1                 0        1          12   60.613563
# 4              1                 0        1           8   88.080671
# ..           ...               ...      ...         ...         ...
# 307            1                 0        1          34   20.845819
# 308            1                 0        1          22   32.294845
# 309            1                 0        1          12   57.439040
# 310            1                 0        1           6  113.616141
# 311            1                 0        1           4  170.978438
#
#          cpu_time time_unit  \
# 0     1503.323035        ms
# 1     3296.441827        ms
# 2     5749.924185        ms
# 3    11622.533302        ms
# 4    26280.240893        ms
# ..            ...       ...
# 307    781.956727        ms
# 308   1532.530377        ms
# 309   3798.339792        ms
# 310  12350.002664        ms
# 311  25429.971932        ms
#
#                                                  label  \
# 0                                 tml_full/ttbar_mu20/
# 1                                 tml_full/ttbar_mu40/
# 2                                 tml_full/ttbar_mu60/
# 3                                tml_full/ttbar_mu100/
# 4                                tml_full/ttbar_mu200/
# ..                                                 ...
# 307  /home/nwachuch/bld6/traccc/data/tml_full/ttbar...
# 308  /home/nwachuch/bld6/traccc/data/tml_full/ttbar...
# 309  /home/nwachuch/bld6/traccc/data/tml_full/ttbar...
# 310  /home/nwachuch/bld6/traccc/data/tml_full/ttbar...
# 311  /home/nwachuch/bld6/traccc/data/tml_full/ttbar...
#
#                                          filename
# 0                                   cuda_cca.json
# 1                                   cuda_cca.json
# 2                                   cuda_cca.json
# 3                                   cuda_cca.json
# 4                                   cuda_cca.json
# ..                                            ...
# 307  stdpar_sparse_ccl_nostdpar_isolated_env.json
# 308  stdpar_sparse_ccl_nostdpar_isolated_env.json
# 309  stdpar_sparse_ccl_nostdpar_isolated_env.json
# 310  stdpar_sparse_ccl_nostdpar_isolated_env.json
# 311  stdpar_sparse_ccl_nostdpar_isolated_env.json
#
# [312 rows x 14 columns]

# %%
import preprocessor

df = preprocessor.transform_dataframe(df)
df
# Out:
#                                    benchmark              algorithm dataset  \
# 0                                   cuda_cca      cca_simplified_sv    mu20
# 1                                   cuda_cca      cca_simplified_sv    mu40
# 2                                   cuda_cca      cca_simplified_sv    mu60
# 3                                   cuda_cca      cca_simplified_sv   mu100
# 4                                   cuda_cca      cca_simplified_sv   mu200
# ..                                       ...                    ...     ...
# 307  stdpar_sparse_ccl_nostdpar_isolated_env  cca_stdpar_sparse_ccl    mu40
# 308  stdpar_sparse_ccl_nostdpar_isolated_env  cca_stdpar_sparse_ccl    mu60
# 309  stdpar_sparse_ccl_nostdpar_isolated_env  cca_stdpar_sparse_ccl   mu100
# 310  stdpar_sparse_ccl_nostdpar_isolated_env  cca_stdpar_sparse_ccl   mu200
# 311  stdpar_sparse_ccl_nostdpar_isolated_env  cca_stdpar_sparse_ccl   mu300
#
#      activations  kernel_time      cpu_time time_unit  iterations  repetitions
# 0         401913    21.277545   1503.323035        ms          33            1
# 1         687499    34.963654   3296.441827        ms          20            1
# 2        1023445    44.425600   5749.924185        ms          16            1
# 3        1716732    60.613563  11622.533302        ms          12            1
# 4        3239265    88.080671  26280.240893        ms           8            1
# ..           ...          ...           ...       ...         ...          ...
# 307       687499    20.845819    781.956727        ms          34            1
# 308      1023445    32.294845   1532.530377        ms          22            1
# 309      1716732    57.439040   3798.339792        ms          12            1
# 310      3239265   113.616141  12350.002664        ms           6            1
# 311      4815527   170.978438  25429.971932        ms           4            1
#
# [312 rows x 9 columns]

# %%
print('List of benchmarks:')
for benchmark in df['benchmark'].unique():
    print(f'- {benchmark}')
# Out:
# List of benchmarks:
# - cuda_cca
# - cuda_cca_geforce_2080
# - seq_cca
# - sparse_ccl_multicore_t16_no_overclock
# - sparse_ccl_multicore_t16_overclocked
# - sparse_ccl_multicore_t1_no_overclock
# - sparse_ccl_multicore_t1_overclocked
# - sparse_ccl_multicore_t2_no_overclock
# - sparse_ccl_multicore_t2_overclocked
# - sparse_ccl_multicore_t32_no_overclock
# - sparse_ccl_multicore_t32_overclocked
# - sparse_ccl_multicore_t4_no_overclock
# - sparse_ccl_multicore_t4_overclocked
# - sparse_ccl_multicore_t64_no_overclock
# - sparse_ccl_multicore_t64_overclocked
# - sparse_ccl_multicore_t72_no_overclock
# - sparse_ccl_multicore_t72_overclocked
# - sparse_ccl_multicore_t8_no_overclock
# - sparse_ccl_multicore_t8_overclocked
# - sparse_ccl_nostdpar_t1_no_overclock
# - sparse_ccl_nostdpar_t1_overclocked
# - stdpar_cca_gpu
# - stdpar_cca_gpu_geforce_2080
# - stdpar_cca_nostdpar
# - stdpar_fast_sv_gpu_isolated_env
# - stdpar_fast_sv_multicore_isolated_env
# - stdpar_fast_sv_nostdpar_isolated_env
# - stdpar_sparse_ccl_gpu_isolated_env
# - stdpar_sparse_ccl_multicore_isolated_env
# - stdpar_sparse_ccl_nostdpar_isolated_env
